# %%
import numpy as np
import time

# %%
def timeNorm(x):
    '''
    Returns the time to generate
    a random normal vector of size x
    '''
    t0 = time.time()
    np.random.normal(0,1,(x,))
    return time.time() - t0

# %%
xvals = [x for x in range(1,10001)]
yvals = [timeNorm(x) for x in xvals]

# %%
import matplotlib.pyplot as pplot
pplot.plot(xvals,yvals)
pplot.show()

# %%
import pickle
with open('results/rflsm_spots_shallow_converge_removeextra.pkl', 'rb') as f:
    mynewlist = pickle.load(f)

# %%
import matplotlib.pyplot as pplot
import numpy as np
for x in list(mynewlist.keys())[1:]:
    plotvalues = list(mynewlist[x].values())
    pplot.plot(mynewlist[x].keys(),plotvalues,label=x)
pplot.legend()
pplot.xlabel('Spot')
pplot.ylabel('Price')
pplot.show()
# Out:
# 0.5651709724200658
# 0.5651766028943146

# %%
trim_dict = {}
for x in mynewlist:
    trim_dict[x] = {}
    for y in mynewlist[x].keys():
            if y != 99.9:
                trim_dict[x][y] = mynewlist[x][y]

# %%
trim_dict
# Out:
# {'BS Digital Call': {80.0: 0.129652332858702,
#   80.68620689655172: 0.13882818952081477,
#   81.37241379310345: 0.1483510641523971,
#   82.05862068965517: 0.1582133670766666,
#   82.7448275862069: 0.16840629895469794,
#   83.43103448275862: 0.17891989920990775,
#   84.11724137931034: 0.18974310145907555,
#   84.80344827586207: 0.20086379527444115,
#   85.48965517241379: 0.21226889356565035,
#   86.17586206896551: 0.22394440484496664,
#   86.86206896551724: 0.235875509623894,
#   87.54827586206896: 0.24804664018366954,
#   88.23448275862069: 0.2604415629654041,
#   88.92068965517241: 0.2730434628372981,
#   89.60689655172413: 0.2858350285156006,
#   90.29310344827587: 0.29879853844200505,
#   90.97931034482758: 0.31191594645217235,
#   91.66551724137932: 0.3251689666072103,
#   92.35172413793103: 0.33853915660132705,
#   93.03793103448277: 0.3520079992037796,
#   93.72413793103449: 0.3655569812407171,
#   94.41034482758621: 0.3791676696719685,
#   95.09655172413794: 0.392821784368338,
#   95.78275862068966: 0.40650126724602953,
#   96.46896551724139: 0.4201883474656911,
#   97.15517241379311: 0.4338656024537362,
#   97.84137931034483: 0.4475160145525389,
#   98.52758620689656: 0.4611230231533807,
#   99.21379310344828: 0.4746705722112515},
#  'LSM Digital Call': {80.0: 0.2447930374102112,
#   80.68620689655172: 0.26276203289077155,
#   81.37241379310345: 0.28093350038500686,
#   82.05862068965517: 0.30051359905517916,
